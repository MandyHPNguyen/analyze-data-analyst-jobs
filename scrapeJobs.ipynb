# %% [markdown]
# # Scrape Jobs from Google Search

# %% [markdown]
# ## Libraries

# %%
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install pandas
from pandas import pandas as pd

# !{sys.executable} -m pip install google-search-results
# https://github.com/serpapi/google-search-results-python
from serpapi import GoogleSearch

import m_creds
# Out:
# Requirement already satisfied: pip in /usr/local/python/3.10.4/lib/python3.10/site-packages (22.3.1)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /home/codespace/.local/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas) (2022.6)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: google-search-results in /usr/local/python/3.10.4/lib/python3.10/site-packages (2.4.1)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.10/site-packages (from google-search-results) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests->google-search-results) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests->google-search-results) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests->google-search-results) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests->google-search-results) (3.4)

# %% [markdown]
# ## Define Parameters

# %%
search_term = "Data Analyst"
search_location = "United States"

params = {
    "api_key": m_creds.m_serpapi,
    "device": "desktop",
    "engine": "google_jobs",
    "google_domain":"google.com",
    "q": search_term,
    "hl": "en",
    "gl": "us",
    "location": search_location,
    "chips": "date_posted:today",
    "start": 0
}

# %%
search = GoogleSearch(params)

# %%
results = search.get_dict()
jobs_df = results['jobs_results']
jobs_df = pd.DataFrame(jobs_df)
jobs_df = pd.concat(
    [pd.DataFrame(jobs_df),
    pd.json_normalize(jobs_df['detected_extensions'])],
    axis=1).drop('detected_extensions', 1)

jobs_df
# Out:
# https://serpapi.com/search
# /tmp/ipykernel_9589/2880632930.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   axis=1).drop('detected_extensions', 1)
#                      title                      company_name  \
# 0           Data Analyst I                              Dice
# 1          Data Analyst II                   Cox Enterprises
# 2  Data Analyst - Swisslog                          Swisslog
# 3             Data Analyst  Blue Rose Consulting Group, Inc.
# 4          Sr Data Analyst                            GitHub
# 5   Marketing Data Analyst                            Upwork
# 6    Business Data Analyst                     Addison Group
# 7    Business Data Analyst           Public Partnerships LLC
# 8      Senior Data Analyst                            Humana
# 9             Data Analyst                         sdg group
#
#               location                                   via  \
# 0        United States                          via LinkedIn
# 1             Anywhere  via Careers At Cox - Cox Enterprises
# 2        United States                          via Swisslog
# 3             Anywhere                          via LinkedIn
# 4             Anywhere                      via Startup Jobs
# 5             Anywhere                            via Upwork
# 6    Oklahoma City, OK                          via LinkedIn
# 7  Cammack Village, AR                            via Adzuna
# 8             Anywhere                          via The Muse
# 9        United States                            via Indeed
#
#                                          description  \
# 0  Dice is the leading career destination for tec...
# 1  Responsible for measuring and assessing techni...
# 2  Data Analyst Mason, Ohio With guidance from se...
# 3  Blue Rose is seeking a Data Analyst to support...
# 4  GitHub’s Revenue Analytics team is on a missio...
# 5  Pulling data from various sources, including S...
# 6  Are you looking for a growth opportunity for a...
# 7  Public Partnerships LLC supports individuals w...
# 8  Description\n\nThe Senior Data Analyst coordin...
# 9  Who Are We?\n\nSDG Group is a global consultin...
#
#                                            thumbnail  \
# 0  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1                                                NaN
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 5                                                NaN
# 6  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 7  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 8  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 9  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                           extensions  \
# 0    [14 hours ago, Contractor, No degree mentioned]
# 1           [9 hours ago, Work from home, Full-time]
# 2  [1 hour ago, Full-time, Health insurance, Dent...
# 3          [12 hours ago, Work from home, Full-time]
# 4  [17 hours ago, Work from home, Full-time, No d...
# 5  [19 hours ago, 30–53 an hour, Work from home, ...
# 6  [10 hours ago, Full-time, Health insurance, De...
# 7                          [21 hours ago, Full-time]
# 8          [18 hours ago, Work from home, Full-time]
# 9  [4 hours ago, Full-time, Health insurance, Den...
#
#                                               job_id     posted_at  \
# 0  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QgSSIsImh0aW...  14 hours ago
# 1  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QgSUkiLCJodG...   9 hours ago
# 2  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QgLSBTd2lzc2...    1 hour ago
# 3  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...  12 hours ago
# 4  eyJqb2JfdGl0bGUiOiJTciBEYXRhIEFuYWx5c3QiLCJodG...  17 hours ago
# 5  eyJqb2JfdGl0bGUiOiJNYXJrZXRpbmcgRGF0YSBBbmFseX...  19 hours ago
# 6  eyJqb2JfdGl0bGUiOiJCdXNpbmVzcyBEYXRhIEFuYWx5c3...  10 hours ago
# 7  eyJqb2JfdGl0bGUiOiJCdXNpbmVzcyBEYXRhIEFuYWx5c3...  21 hours ago
# 8  eyJqb2JfdGl0bGUiOiJTZW5pb3IgRGF0YSBBbmFseXN0Ii...  18 hours ago
# 9  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...   4 hours ago
#
#   schedule_type work_from_home         salary
# 0    Contractor            NaN            NaN
# 1     Full-time           True            NaN
# 2     Full-time            NaN            NaN
# 3     Full-time           True            NaN
# 4     Full-time           True            NaN
# 5    Contractor           True  30–53 an hour
# 6     Full-time            NaN            NaN
# 7     Full-time            NaN            NaN
# 8     Full-time           True            NaN
# 9     Full-time            NaN            NaN
